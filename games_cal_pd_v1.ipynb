# %%
#######import libraries
### For data
import pandas as pd
import numpy as np

# %%
### Specify the urls and tables to scrape
switch1 = pd.read_html("https://en.wikipedia.org/wiki/List_of_Nintendo_Switch_games", header=[1])[0]
switch2 = pd.read_html("https://en.wikipedia.org/wiki/List_of_Nintendo_Switch_games_(M-Z)", header=[1])[0]
xbox1 = pd.read_html("https://en.wikipedia.org/wiki/List_of_Xbox_One_games_(A-L)", header=[1])[1]
xbox2 = pd.read_html("https://en.wikipedia.org/wiki/List_of_Xbox_One_games_(M-Z)", header=[1])[1]
ps41 = pd.read_html("https://en.wikipedia.org/wiki/List_of_PlayStation_4_games", header=[1])[0]
ps42 = pd.read_html("https://en.wikipedia.org/wiki/List_of_PlayStation_4_games_(M-Z)", header=[1])[0]
## PC A - "https://en.wikipedia.org/wiki/List_of_PC_games_(A)"
## PC Z - "https://en.wikipedia.org/wiki/List_of_PC_games_(Z)"
## PC 0-9 - "https://en.wikipedia.org/wiki/List_of_PC_games_(Numerical)"

# %%
### Check DataFrame results
#switch1
#switch2
#xbox1
#xbox2
#ps41
#ps42

# %%
### Append column for platform
switch1['Platform'] = 'Nintendo Switch'
switch2['Platform'] = 'Nintendo Switch'
xbox1['Platform'] = 'Xbox One'
xbox2['Platform'] = 'Xbox One'
ps41['Platform'] = 'Playstation 4'
ps42['Platform'] = 'Playstation 4'

# %%
### Delete unnessacary columns
switch1 = switch1.drop(['Ref.'], axis=1)
switch2 = switch2.drop(['Ref.'], axis=1)
xbox1 = xbox1.drop(['Ref.','Addons'], axis=1)
xbox2 = xbox2.drop(['Ref.','Addons'], axis=1)
ps41 = ps41.drop(['Ref.','Addons'], axis=1)
ps42 = ps42.drop(['Ref.','Addons'], axis=1)

# %%
### Create new alt columns to seperate non-date values
### Values contain [case sensitive]: Unreleased, Asia, China, TBA

temp=df.JP.fillna('NaN')
df['JP_alt'] = np.where(temp.str.contains('NaN'), 'NaN',
                    pd.np.where(temp.str.contains('Unreleased'), 'Unreleased',
                    pd.np.where(temp.str.contains('Asia'), 'Asia Exclusive',
                    pd.np.where(temp.str.contains('China'), 'China Exclusive',
                    pd.np.where(temp.str.contains('TBA'), 'TBA', 'NaN')))))

temp=df.EU.fillna('NaN')
df['EU_alt'] = np.where(temp.str.contains('NaN'), 'NaN',
                    pd.np.where(temp.str.contains('Unreleased'), 'Unreleased',
                    pd.np.where(temp.str.contains('Asia'), 'Asia Exclusive',
                    pd.np.where(temp.str.contains('China'), 'China Exclusive',
                    pd.np.where(temp.str.contains('TBA'), 'TBA', 'NaN')))))

temp=df.NA.fillna('NaN')
df['NA_alt'] = np.where(temp.str.contains('NaN'), 'NaN',
                    pd.np.where(temp.str.contains('Unreleased'), 'Unreleased',
                    pd.np.where(temp.str.contains('Asia'), 'Asia Exclusive',
                    pd.np.where(temp.str.contains('China'), 'China Exclusive',
                    pd.np.where(temp.str.contains('TBA'), 'TBA', 'NaN')))))

temp=df.PAL.fillna('NaN')
df['PAL_alt'] = np.where(temp.str.contains('NaN'), 'NaN',
                    pd.np.where(temp.str.contains('Unreleased'), 'Unreleased',
                    pd.np.where(temp.str.contains('Asia'), 'Asia Exclusive',
                    pd.np.where(temp.str.contains('China'), 'China Exclusive',
                    pd.np.where(temp.str.contains('TBA'), 'TBA', 'NaN')))))

df
# Out:
#                                                   Title  \
# 0                                  #Breakforcist Battle
# 1                                       #killallzombies
# 2                                            1-2-Switch
# 3                                 10 Second Run Returns
# 4                                   12 is Better Than 6
# 5                                                  198X
# 6                     2064: Read Only Memories Integral
# 7                                                  20XX
# 8                               30-in-1 Game Collection
# 9                              36 Fragments of Midnight
# 10                                          3D MiniGolf
# 11                                          60 Seconds!
# 12                                        6180 the moon
# 13                                     7 Billion Humans
# 14                                         8-Bit Armies
# 15                                       8-Bit Invaders
# 16                         88 Heroes: 98 Heroes Edition
# 17                                 9 Monkeys of Shaolin
# 18                                         90s Super GP
# 19                                              99Moves
# 20                                            99Seconds
# 21                                              99Vidas
# 22                                          A-Kei Otaku
# 23                                          A Dark Room
# 24                                        A Hat in Time
# 25                                                 Abzû
# 26                                        Access Denied
# 27                                       Ace of Seafood
# 28                      Aces of the Luftwaffe: Squadron
# 29                             Achtung! Cthulhu Tactics
# ...                                                 ...
# 6070                                     Yakuza: Kiwami
# 6071                                    Yakuza Kiwami 2
# 6072                              Yakuza: Like a Dragon
# 6073                   The Yakuza Remastered Collection
# 6074                                  Yesterday Origins
# 6075                                     Yo-kai Watch 4
# 6076                              Yoku's Island Express
# 6077                         Yomawari: Midnight Shadows
# 6078               Yonder: The Cloud Catcher Chronicles
# 6079                                       Yooka-Laylee
# 6080               Yooka-Laylee and the Impossible Lair
# 6081                            Ys: Memories of Celceta
# 6082                                          Ys Origin
# 6083                         Ys VIII: Lacrimosa of Dana
# 6084                                Ys IX: Monstrum Nox
# 6085                    Yu-Gi-Oh! Legacy of the Duelist
# 6086  YU-NO: A Girl Who Chants Love at the Bound of ...
# 6087                         Zanki Zero: Last Beginning
# 6088                                             Zenith
# 6089                      Zero Escape: The Nonary Games
# 6090                                  Zero Time Dilemma
# 6091                                 Zhanguo Pohuaishen
# 6092                                             Zheros
# 6093                                           Ziggurat
# 6094                                              Zombi
# 6095                                Zombie Army Trilogy
# 6096                            Zombie Army 4: Dead War
# 6097                                     Zombie Vikings
# 6098          Zone of the Enders: The 2nd Runner – Mars
# 6099                                             Zotrix
#
#                                 Genre(s)                Developer(s)  \
# 0                                  Party           Lucid Sheep Games
# 1           Survivalthird-person shooter                 Beatshapers
# 2                                  Party                Nintendo EPD
# 3                            Partyracing                  Blue Print
# 4                              Adventure            Ink Stains Games
# 5                                 Arcade              Hi-Bit Studios
# 6                              Adventure                     MidBoss
# 7                             Platformer         Batterystaple Games
# 8                                 Arcade               Digital Bards
# 9                             Platformer                Petite Games
# 10                                Sports                    Joindots
# 11                             Adventure             Robot Gentleman
# 12                            Platformer  Turtle CreamPokPoong Games
# 13                                Puzzle        Tomorrow Corporation
# 14                    Real-time strategy            Petroglyph Games
# 15                    Real-time strategy            Petroglyph Games
# 16                            Platformer               Bitmap Bureau
# 17                           Beat 'em up               Sobaka Studio
# 18                                Racing            NicalisPelikan13
# 19                                Action               EnjoyUp Games
# 20                                Action               EnjoyUp Games
# 21                           Beat 'em up          QUByte Interactive
# 22                          Visual novel                  Worker Bee
# 23                             Adventure     Scratchwork Development
# 24                      Action-adventure         Gears for Breakfast
# 25                             Adventure         Giant Squid Studios
# 26                                Puzzle               Stately Snail
# 27                          Shoot 'em up                     Nussoft
# 28                          Shoot 'em up                  HandyGames
# 29                 Tactical role-playing              Auroch Digital
# ...                                  ...                         ...
# 6070                              Action                        Sega
# 6071                    Action-adventure                        Sega
# 6072                    Action-adventure                        Sega
# 6073                    Action-adventure                        Sega
# 6074                           Adventure             Pendulo Studios
# 6075                        Role-playing                     Level-5
# 6076      Platformer, adventure, pinball               Villa Gorilla
# 6077                     Survival horror        Nippon Ichi Software
# 6078                        Role-playing              Prideful Sloth
# 6079                       3D platformer             Playtonic Games
# 6080                       3D platformer             Playtonic Games
# 6081                 Action role-playing                Nihon Falcom
# 6082                 Action role-playing                Nihon Falcom
# 6083                 Action role-playing                Nihon Falcom
# 6084                 Action role-playing                Nihon Falcom
# 6085                        Card & board            Other Ocean Int.
# 6086                        Visual novel                        5pb.
# 6087                        Role-playing              Spike Chunsoft
# 6088                        Role-playing             Infinigon Games
# 6089                           Adventure              Spike Chunsoft
# 6090                           Adventure                       Chime
# 6091                                 NaN                       Giant
# 6092                              Action            Rimlight Studios
# 6093                     Dungeon crawler           Milkstone Studios
# 6094                First-person shooter                     Ubisoft
# 6095                    Tactical shooter      Rebellion Developments
# 6096                    Tactical shooter      Rebellion Developments
# 6097                              Action                 Zoink Games
# 6098  Hack and slashthird-person shooter               CygamesKonami
# 6099                        Shoot 'em up               Zerobit Games
#
#                            Publisher(s)                                   JP  \
# 0                     Lucid Sheep Games                           Unreleased
# 1                           Beatshapers                           Unreleased
# 2                              Nintendo                        March 3, 2017
# 3                            Blue Print                    December 21, 2017
# 4                     HypeTrain Digital                           Unreleased
# 5                        Hi-Bit Studios                           Unreleased
# 6                               MidBoss                    December 27, 2018
# 7                   Batterystaple Games                        July 10, 2018
# 8                         Digital Bards                    February 21, 2019
# 9     JP: Rainy FrogWW: Ratalaika Games                   September 27, 2017
# 10                             Joindots                           Unreleased
# 11                      Robot Gentleman                           Unreleased
# 12                         Turtle Cream                        June 21, 2018
# 13                 Tomorrow Corporation                     October 25, 2018
# 14                             Soedesco                           Unreleased
# 15                             Soedesco                           Unreleased
# 16                    Rising Star Games                     October 12, 2017
# 17                   Buka Entertainment                           Unreleased
# 18                              Nicalis                           Unreleased
# 19        JP: StarsignWW: EnjoyUp Games                       March 14, 2019
# 20        JP: StarsignWW: EnjoyUp Games                        March 7, 2019
# 21                   QUByte Interactive                           Unreleased
# 22                           Worker Bee                     January 10, 2019
# 23                 Circle Entertainment                           Unreleased
# 24                        Humble Bundle                     October 18, 2019
# 25                            505 Games                           Unreleased
# 26                      Ratalaika Games                        June 27, 2019
# 27                              Nussoft                    February 22, 2018
# 28         JP: Worker BeeWW: HandyGames                        June 14, 2018
# 29                             Ripstone                           Unreleased
# ...                                 ...                                  ...
# 6070                               Sega                         Jan 21, 2016
# 6071                               Sega                         Dec 17, 2017
# 6072                               Sega                         Jan 16, 2019
# 6073                               Sega                         Feb 11, 2020
# 6074                             Anuman                           Unreleased
# 6075                            Level-5                                  TBA
# 6076                             Team17                         May 29, 2018
# 6077                        NIS America                         Aug 24, 2017
# 6078                     Prideful Sloth                           Unreleased
# 6079                             Team17                         Apr 11, 2017
# 6080                             Team17                          Oct 8, 2019
# 6081                       Nihon Falcom                         May 16, 2019
# 6082                      Marvelous USA                         Feb 21, 2017
# 6083                       Nihon Falcom                         May 25, 2017
# 6084                       Nihon Falcom                         Sep 26, 2019
# 6085                             Konami                           Unreleased
# 6086                               5pb.                         Feb 18, 2016
# 6087                     Spike Chunsoft                          Jul 5, 2018
# 6088                      BadLand Indie                          Jul 3, 2017
# 6089                        Aksys Games                         Apr 13, 2017
# 6090                     Spike Chunsoft                         Aug 17, 2017
# 6091                              Giant  Released exclusively in China (TBA)
# 6092                   Rimlight Studios                           Unreleased
# 6093                  Milkstone Studios                           Unreleased
# 6094                            Ubisoft                         Aug 19, 2015
# 6095                          505 Games                          Mar 6, 2015
# 6096                          505 Games                                 2020
# 6097                        Zoink Games                          Sep 2, 2015
# 6098                             Konami                          Sep 6, 2018
# 6099                      UFO Int Games                           Unreleased
#
#                                        NA                 PAL          Ref.  \
# 0                          April 12, 2018      April 12, 2018           [5]
# 1                        January 24, 2019    January 24, 2019           [6]
# 2                           March 3, 2017       March 3, 2017           NaN
# 3                        January 25, 2018   February 22, 2018           [7]
# 4                           March 5, 2019       March 5, 2019           [8]
# 5                                    2019                2019           [9]
# 6                         August 14, 2018     August 14, 2018           NaN
# 7                           July 10, 2018       July 10, 2018           NaN
# 8                            May 30, 2019        May 30, 2019  [10][11][12]
# 9                      September 14, 2017  September 14, 2017          [13]
# 10                       February 1, 2018    February 1, 2018          [14]
# 11                      December 18, 2017   December 18, 2017          [15]
# 12                           May 24, 2018        May 31, 2018           NaN
# 13                       October 25, 2018    October 25, 2018           NaN
# 14                     September 21, 2018  September 21, 2018           NaN
# 15                     September 26, 2018  September 26, 2018           NaN
# 16                       October 12, 2017    October 12, 2017          [16]
# 17                                   2019                2019           NaN
# 18                                    TBA                 TBA          [17]
# 19                       February 8, 2019    February 8, 2019      [18][19]
# 20                        January 4, 2019     January 4, 2019  [20][21][22]
# 21                      November 27, 2018   November 27, 2018           NaN
# 22                             Unreleased          Unreleased          [23]
# 23                         April 11, 2019      April 12, 2019      [24][25]
# 24                       October 18, 2019    October 18, 2019           NaN
# 25                      November 29, 2018   November 29, 2018           NaN
# 26                       February 8, 2019    February 8, 2019          [18]
# 27                      February 22, 2018   February 22, 2018          [26]
# 28                      November 17, 2017   November 17, 2017          [27]
# 29                       January 24, 2019    January 24, 2019          [28]
# ...                                   ...                 ...           ...
# 6070                         Aug 29, 2017                 NaN           NaN
# 6071                         Aug 28, 2018                 NaN           NaN
# 6072                                 2020                 NaN           NaN
# 6073                         Feb 11, 2020                 NaN         [107]
# 6074                         Nov 17, 2016                 NaN           NaN
# 6075                           Unreleased                 NaN           NaN
# 6076                         May 29, 2018                 NaN           NaN
# 6077                         Oct 24, 2017                 NaN           NaN
# 6078                         Jul 18, 2017                 NaN           NaN
# 6079                         Apr 11, 2017                 NaN           NaN
# 6080                          Oct 8, 2019                 NaN           NaN
# 6081                           Unreleased                 NaN           NaN
# 6082                         Feb 21, 2017                 NaN           NaN
# 6083                         Sep 12, 2017                 NaN           NaN
# 6084                           Unreleased                 NaN           NaN
# 6085                         Jul 30, 2015                 NaN           NaN
# 6086                          Oct 1, 2019                 NaN           NaN
# 6087                          Apr 9, 2019                 NaN          [48]
# 6088                         Sep 20, 2016                 NaN         [104]
# 6089                         Mar 24, 2017                 NaN          [93]
# 6090                         Aug 18, 2017                 NaN          [69]
# 6091  Released exclusively in China (TBA)                 NaN           [4]
# 6092                         Nov 14, 2016                 NaN           NaN
# 6093                         Apr 21, 2015                 NaN          [58]
# 6094                         Aug 18, 2015                 NaN          [26]
# 6095                          Mar 6, 2015                 NaN          [56]
# 6096                                 2020                 NaN           NaN
# 6097                          Sep 1, 2015                 NaN           NaN
# 6098                          Sep 4, 2018                 NaN           NaN
# 6099                          Dec 8, 2015                 NaN         [108]
#
#              Platform                                   EU Addons  \
# 0     Nintendo Switch                                  NaN    NaN
# 1     Nintendo Switch                                  NaN    NaN
# 2     Nintendo Switch                                  NaN    NaN
# 3     Nintendo Switch                                  NaN    NaN
# 4     Nintendo Switch                                  NaN    NaN
# 5     Nintendo Switch                                  NaN    NaN
# 6     Nintendo Switch                                  NaN    NaN
# 7     Nintendo Switch                                  NaN    NaN
# 8     Nintendo Switch                                  NaN    NaN
# 9     Nintendo Switch                                  NaN    NaN
# 10    Nintendo Switch                                  NaN    NaN
# 11    Nintendo Switch                                  NaN    NaN
# 12    Nintendo Switch                                  NaN    NaN
# 13    Nintendo Switch                                  NaN    NaN
# 14    Nintendo Switch                                  NaN    NaN
# 15    Nintendo Switch                                  NaN    NaN
# 16    Nintendo Switch                                  NaN    NaN
# 17    Nintendo Switch                                  NaN    NaN
# 18    Nintendo Switch                                  NaN    NaN
# 19    Nintendo Switch                                  NaN    NaN
# 20    Nintendo Switch                                  NaN    NaN
# 21    Nintendo Switch                                  NaN    NaN
# 22    Nintendo Switch                                  NaN    NaN
# 23    Nintendo Switch                                  NaN    NaN
# 24    Nintendo Switch                                  NaN    NaN
# 25    Nintendo Switch                                  NaN    NaN
# 26    Nintendo Switch                                  NaN    NaN
# 27    Nintendo Switch                                  NaN    NaN
# 28    Nintendo Switch                                  NaN    NaN
# 29    Nintendo Switch                                  NaN    NaN
# ...               ...                                  ...    ...
# 6070    Playstation 4                         Aug 29, 2017    NaN
# 6071    Playstation 4                         Aug 28, 2018      P
# 6072    Playstation 4                                 2020    NaN
# 6073    Playstation 4                         Feb 11, 2020    NaN
# 6074    Playstation 4                         Nov 21, 2016    NaN
# 6075    Playstation 4                           Unreleased    NaN
# 6076    Playstation 4                         May 29, 2018    NaN
# 6077    Playstation 4                         Oct 27, 2017      P
# 6078    Playstation 4                         Jul 18, 2017    NaN
# 6079    Playstation 4                         Apr 11, 2017    NaN
# 6080    Playstation 4                          Oct 8, 2019    NaN
# 6081    Playstation 4                           Unreleased      P
# 6082    Playstation 4                         Feb 21, 2017    NaN
# 6083    Playstation 4                         Sep 15, 2017      P
# 6084    Playstation 4                           Unreleased    NaN
# 6085    Playstation 4                           Unreleased    NaN
# 6086    Playstation 4                          Oct 4, 2019    NaN
# 6087    Playstation 4                          Apr 9, 2019    NaN
# 6088    Playstation 4                         Sep 20, 2016    NaN
# 6089    Playstation 4                         Mar 24, 2017    NaN
# 6090    Playstation 4                         Sep 22, 2017    NaN
# 6091    Playstation 4  Released exclusively in China (TBA)    NaN
# 6092    Playstation 4                         Nov 14, 2016    NaN
# 6093    Playstation 4                         Apr 22, 2015    NaN
# 6094    Playstation 4                         Aug 18, 2015    NaN
# 6095    Playstation 4                          Mar 6, 2015     3D
# 6096    Playstation 4                                 2020    NaN
# 6097    Playstation 4                          Sep 1, 2015    NaN
# 6098    Playstation 4                          Sep 6, 2018   P VR
# 6099    Playstation 4                          Jan 8, 2016    NaN
#
#                JP_alt           EU_alt           NA_alt     PAL_alt
# 0          Unreleased              NaN              NaN         NaN
# 1          Unreleased              NaN              NaN         NaN
# 2                 NaN              NaN              NaN         NaN
# 3                 NaN              NaN              NaN         NaN
# 4          Unreleased              NaN              NaN         NaN
# 5          Unreleased              NaN              NaN         NaN
# 6                 NaN              NaN              NaN         NaN
# 7                 NaN              NaN              NaN         NaN
# 8                 NaN              NaN              NaN         NaN
# 9                 NaN              NaN              NaN         NaN
# 10         Unreleased              NaN              NaN         NaN
# 11         Unreleased              NaN              NaN         NaN
# 12                NaN              NaN              NaN         NaN
# 13                NaN              NaN              NaN         NaN
# 14         Unreleased              NaN              NaN         NaN
# 15         Unreleased              NaN              NaN         NaN
# 16                NaN              NaN              NaN         NaN
# 17         Unreleased              NaN              NaN         NaN
# 18         Unreleased              NaN              TBA         TBA
# 19                NaN              NaN              NaN         NaN
# 20                NaN              NaN              NaN         NaN
# 21         Unreleased              NaN              NaN         NaN
# 22                NaN              NaN       Unreleased  Unreleased
# 23         Unreleased              NaN              NaN         NaN
# 24                NaN              NaN              NaN         NaN
# 25         Unreleased              NaN              NaN         NaN
# 26                NaN              NaN              NaN         NaN
# 27                NaN              NaN              NaN         NaN
# 28                NaN              NaN              NaN         NaN
# 29         Unreleased              NaN              NaN         NaN
# ...               ...              ...              ...         ...
# 6070              NaN              NaN              NaN         NaN
# 6071              NaN              NaN              NaN         NaN
# 6072              NaN              NaN              NaN         NaN
# 6073              NaN              NaN              NaN         NaN
# 6074       Unreleased              NaN              NaN         NaN
# 6075              TBA       Unreleased       Unreleased         NaN
# 6076              NaN              NaN              NaN         NaN
# 6077              NaN              NaN              NaN         NaN
# 6078       Unreleased              NaN              NaN         NaN
# 6079              NaN              NaN              NaN         NaN
# 6080              NaN              NaN              NaN         NaN
# 6081              NaN       Unreleased       Unreleased         NaN
# 6082              NaN              NaN              NaN         NaN
# 6083              NaN              NaN              NaN         NaN
# 6084              NaN       Unreleased       Unreleased         NaN
# 6085       Unreleased       Unreleased              NaN         NaN
# 6086              NaN              NaN              NaN         NaN
# 6087              NaN              NaN              NaN         NaN
# 6088              NaN              NaN              NaN         NaN
# 6089              NaN              NaN              NaN         NaN
# 6090              NaN              NaN              NaN         NaN
# 6091  China Exclusive  China Exclusive  China Exclusive         NaN
# 6092       Unreleased              NaN              NaN         NaN
# 6093       Unreleased              NaN              NaN         NaN
# 6094              NaN              NaN              NaN         NaN
# 6095              NaN              NaN              NaN         NaN
# 6096              NaN              NaN              NaN         NaN
# 6097              NaN              NaN              NaN         NaN
# 6098              NaN              NaN              NaN         NaN
# 6099       Unreleased              NaN              NaN         NaN
#
# [6100 rows x 15 columns]

# %%
### Concatenate all tables into one
df = pd.concat([switch1, switch2, xbox1, xbox2, ps41, ps42], ignore_index=True, sort=False)
df.to_csv ('df_v1.csv', index=False, header=True)

# %%
### Convert date columns to datetime
#df['JP'] = pd.to_datetime(df.JP)

#df['JP'] = df['JP'].dt.strftime('%Y-%m-%d')
#df

# %%
### Create new alt columns to seperate non-date values
### Values contain [case sensitive]: Unreleased, Asia, China, TBA

temp=df2.JP.fillna('NaN')
df2['JP_alt'] = np.where(temp.str.contains('NaN'), 'NaN',
                    pd.np.where(temp.str.contains('Unreleased'), 'Unreleased',
                    pd.np.where(temp.str.contains('Asia'), 'Asia Exclusive',
                    pd.np.where(temp.str.contains('China'), 'China Exclusive',
                    pd.np.where(temp.str.contains('TBA'), 'TBA', 'NaN')))))

temp=df2.EU.fillna('NaN')
df2['EU_alt'] = np.where(temp.str.contains('NaN'), 'NaN',
                    pd.np.where(temp.str.contains('Unreleased'), 'Unreleased',
                    pd.np.where(temp.str.contains('Asia'), 'Asia Exclusive',
                    pd.np.where(temp.str.contains('China'), 'China Exclusive',
                    pd.np.where(temp.str.contains('TBA'), 'TBA', 'NaN')))))

temp=df2.NA.fillna('NaN')
df2['NA_alt'] = np.where(temp.str.contains('NaN'), 'NaN',
                    pd.np.where(temp.str.contains('Unreleased'), 'Unreleased',
                    pd.np.where(temp.str.contains('Asia'), 'Asia Exclusive',
                    pd.np.where(temp.str.contains('China'), 'China Exclusive',
                    pd.np.where(temp.str.contains('TBA'), 'TBA', 'NaN')))))

temp=df2.PAL.fillna('NaN')
df2['PAL_alt'] = np.where(temp.str.contains('NaN'), 'NaN',
                    pd.np.where(temp.str.contains('Unreleased'), 'Unreleased',
                    pd.np.where(temp.str.contains('Asia'), 'Asia Exclusive',
                    pd.np.where(temp.str.contains('China'), 'China Exclusive',
                    pd.np.where(temp.str.contains('TBA'), 'TBA', 'NaN')))))

df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-03f79a1fb651> in <module>
#       2 ### Values contain [case sensitive]: Unreleased, Asia, China, TBA
#       3
# ----> 4 temp=df2.JP.fillna('NaN')
#       5 df2['JP_alt'] = np.where(temp.str.contains('NaN'), 'NaN',
#       6                     pd.np.where(temp.str.contains('Unreleased'), 'Unreleased',
#
# NameError: name 'df2' is not defined

# %%
### Create new columns to extract date values

# %%
### Format dates to all be in the same format [Multiple formats in the same columns exist]

# %%
### Create binary columns for each genre - 1/0 values
### Genres:

# %%
### Sort by title, reset index, specify columns and show dataframe result
df2 = df.sort_values('Title')
df2 = df2.reset_index(drop=True)
df2 = df2[['Title','Platform','Genre(s)','Developer(s)','Publisher(s)','JP','EU','NA','PAL','JP_alt','EU_alt','NA_alt','PAL_alt']]
df2

# %%
### Export dataframe result to CSV
df2.to_csv ('df_final.csv', index=False, header=True)
